# %%
import yfinance as yf
import pandas

# %%
msft=yf.Ticker("msft")
msfthist = msft.history(start="2023-05-05", end="2023-05-06", interval='1m')['Close']
msfthist.plot()
# Out:
# <AxesSubplot: xlabel='Datetime'>
