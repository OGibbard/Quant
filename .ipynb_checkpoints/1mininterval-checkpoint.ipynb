# %%
import yfinance as yf
import pandas

# %%
msft=yf.Ticker('MSFT')
aapl=yf.Ticker('AAPL')

# %%
msfthist = msft.history(period='1wk')['Close']
aaplhist = aapl.history(period='1wk')['Close']
msfthist.plot()
aaplhist.plot()
# Out:
# <AxesSubplot: xlabel='Date'>
