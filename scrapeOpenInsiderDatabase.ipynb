# %%
import requests
from bs4 import BeautifulSoup

def ChangeDate(month, day, year):
    if day>1:
        day = day-1
    else:
        if month>1:
            day = 31
            month = month-1
        else:
            year = year -1
            day = 31
            month = 12
    return month, day, year

currentMonth = 5
currentDay = 12
currentYear = 2023
totalScrapedInfo=[]

#7198
while currentYear>2002:
    currentMonth, currentDay, currentYear = ChangeDate(currentMonth, currentDay, currentYear)
    firstPart='http://openinsider.com/screener?s=&o=&pl=&ph=&ll=&lh=&fd=-1&fdr='
    secondPart='&td=0&tdr=&fdlyl=&fdlyh=&daysago=&xp=1&xs=1&vl=&vh=&ocl=&och=&sic1=-1&sicl=100&sich=9999&grp=0&nfl=&nfh=&nil=&nih=&nol=&noh=&v2l=&v2h=&oc2l=&oc2h=&sortcol=0&cnt=1000&page=1'
    currentDate = (str(currentMonth)+'%2F'+str(currentDay)+'%2F'+str(currentYear)+'+-+'+str(currentMonth)+'%2F'+str(currentDay)+'%2F'+str(currentYear))
    link = firstPart+currentDate+secondPart
    page = requests.get(link) # Getting page HTML through request
    soup = BeautifulSoup(page.content, 'html.parser') # Parsing content using beautifulsoup
    data = soup.select("table.tinytable tr td") # Selecting all of the anchors with titles
    
    print(currentMonth,currentDay,currentYear)

    for anchor in data:
        scrapedInfo = {
            "title": anchor.text
        }
        totalScrapedInfo.append(scrapedInfo)
# Out:
# 5 11 2023
# 5 10 2023
# 5 9 2023
# 5 8 2023
# 5 7 2023
# 5 6 2023
# 5 5 2023
# 5 4 2023
# 5 3 2023
# 5 2 2023
# 5 1 2023
# 4 31 2023
# 4 30 2023
# 4 29 2023
# 4 28 2023
# 4 27 2023
# 4 26 2023
# 4 25 2023
# 4 24 2023
# 4 23 2023
# 4 22 2023
# 4 21 2023
# 4 20 2023
# 4 19 2023
# 4 18 2023
# 4 17 2023
# 4 16 2023
# 4 15 2023
# 4 14 2023
# 4 13 2023
# 4 12 2023
# 4 11 2023
# 4 10 2023
# 4 9 2023
# 4 8 2023
# 4 7 2023
# 4 6 2023
# 4 5 2023
# 4 4 2023
# 4 3 2023
# 4 2 2023
# 4 1 2023
# 3 31 2023
# 3 30 2023
# 3 29 2023
# 3 28 2023
# 3 27 2023
# 3 26 2023
# 3 25 2023
# 3 24 2023
# 3 23 2023
# 3 22 2023
# 3 21 2023
# 3 20 2023
# 3 19 2023
# 3 18 2023
# 3 17 2023
# 3 16 2023
# 3 15 2023
# 3 14 2023
# 3 13 2023
# 3 12 2023
# 3 11 2023
# 3 10 2023
# 3 9 2023
# 3 8 2023
# 3 7 2023
# 3 6 2023
# 3 5 2023
# 3 4 2023
# 3 3 2023
# 3 2 2023
# 3 1 2023
# 2 31 2023
# 2 30 2023
# 2 29 2023
# 2 28 2023
# 2 27 2023
# 2 26 2023
# 2 25 2023
# 2 24 2023
# 2 23 2023
# 2 22 2023
# 2 21 2023
# 2 20 2023
# ...

# %%
k=0
columns=17
file = open('../data/insiderTradingDataFull.csv', 'w')
for stock in totalScrapedInfo:
    k=k+1
    temp=(str(*stock.values())).replace(',', '')
    if temp!='':
        if 1<k<14:
            file.write(temp+',')
    if k==columns:
        file.write('\n')
        k=0
file.close()
print('done')
